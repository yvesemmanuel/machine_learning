# %% [markdown]
# #### data

# %%
from mnist_loader import load_data_wrapper, load_data

# %%
training_data, validation_data, test_data = load_data_wrapper()

# %% [markdown]
# #### training

# %%
from network import Network

net = Network([784, 30, 10])

# %%
net.SGD(training_data, 50, 10, 0.2, test_data)
# Out:
# Epoch 0: 0.5889
# Epoch 1: 0.7473
# Epoch 2: 0.7791
# Epoch 3: 0.857
# Epoch 4: 0.8768
# Epoch 5: 0.8859
# Epoch 6: 0.8941
# Epoch 7: 0.8989
# Epoch 8: 0.9032
# Epoch 9: 0.9067
# Epoch 10: 0.91
# Epoch 11: 0.9129
# Epoch 12: 0.9154
# Epoch 13: 0.917
# Epoch 14: 0.9181
# Epoch 15: 0.9193
# Epoch 16: 0.9219
# Epoch 17: 0.9224
# Epoch 18: 0.9235
# Epoch 19: 0.9258
# Epoch 20: 0.9264
# Epoch 21: 0.9265
# Epoch 22: 0.9293
# Epoch 23: 0.9276
# Epoch 24: 0.9295
# Epoch 25: 0.9291
# Epoch 26: 0.9314
# Epoch 27: 0.9306
# Epoch 28: 0.931
# Epoch 29: 0.9311
# Epoch 30: 0.932
# Epoch 31: 0.9322
# Epoch 32: 0.9331
# Epoch 33: 0.9333
# Epoch 34: 0.9339
# Epoch 35: 0.9343
# Epoch 36: 0.9344
# Epoch 37: 0.9338
# Epoch 38: 0.935
# Epoch 39: 0.935
# Epoch 40: 0.935
# Epoch 41: 0.9355
# Epoch 42: 0.9353
# Epoch 43: 0.9359
# Epoch 44: 0.9353
# Epoch 45: 0.9363
# Epoch 46: 0.9355
# Epoch 47: 0.9365
# Epoch 48: 0.937
# Epoch 49: 0.9368

# %%
net.score(test_data)
# Out:
# 0.9368

# %%
net.weights
# Out:
# [array([[-0.41335593,  0.33921539,  1.94139603, ...,  0.54351476,
#          -0.44819465,  0.07775313],
#         [-0.13439133, -1.16528889,  2.61609672, ..., -0.13117627,
#           1.13532124, -0.42774014],
#         [ 0.03288326, -0.0998039 , -0.50754549, ..., -0.837308  ,
#          -0.35013222,  0.06127738],
#         ...,
#         [-0.25306517, -0.99190897, -0.07397272, ..., -0.59381836,
#           0.29388243,  0.24059331],
#         [ 0.42145464,  0.80584055,  1.16311071, ...,  0.31056309,
#           0.64730156, -0.66525056],
#         [-1.72284485, -0.64212494,  1.55894025, ..., -2.04647954,
#          -0.79379261, -1.71142096]]),
#  array([[-6.18676521e-01, -1.31090451e+00,  2.08140098e+00,
#          -1.26851823e+00,  2.47736176e-01,  1.90964639e-02,
#           2.07035536e+00,  3.15497042e+00,  1.27016435e+00,
#           1.42356958e+00,  1.98713270e+00, -2.22770420e+00,
#          -3.95677090e+00, -2.28891912e-01, -2.26938789e+00,
# ...
